# %%
import numpy as np
l = ['apple', 'oragne']
np_l = np.array(l)
print(l)
# Out:
# ['apple', 'oragne']

# %%
import sys
print(sys.prefix)
# Out:
# /home/atanu/anaconda3/envs/MyDS

# %%
import cv2
img = cv2.imread('/home/atanu/Pictures/profile.png')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# QObject::moveToThread: Current thread (0x5581e751d150) is not the object's thread (0x7f09af01b3c0).
# Cannot move to target thread (0x5581e751d150)
#
# ...
